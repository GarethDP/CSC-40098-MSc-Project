# %% [markdown]
# # CNN Model

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd

DATASET_ID = 'FD002' #Change between 'FD001' and 'FD002'
BATCH_SIZE = 256
EPOCHS = 50
INITIAL_LR = 0.003
MAX_GRAD_NORM = 1.0
PATIENCE = 10
SEEDS = [42, 101, 2024, 7, 88, 123, 999, 314, 500, 13]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

X_train_arr = np.load(f'../data/processed/X_train_{DATASET_ID}_engine_split.npy')
y_train_arr = np.load(f'../data/processed/y_train_{DATASET_ID}_engine_split.npy')
X_val_arr   = np.load(f'../data/processed/X_val_{DATASET_ID}_engine_split.npy')
y_val_arr   = np.load(f'../data/processed/y_val_{DATASET_ID}_engine_split.npy')

class CMAPSSDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class RUL_CNN(nn.Module):
    def __init__(self, input_features, dropout=0.2):
        super(RUL_CNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=input_features, out_channels=64, kernel_size=3)
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        self.drop1 = nn.Dropout(dropout)
        
        self.conv2 = nn.Conv1d(in_channels=64, out_channels=32, kernel_size=3)
        self.pool2 = nn.MaxPool1d(kernel_size=2)
        self.drop2 = nn.Dropout(dropout)
        
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 6, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = self.drop1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        x = self.drop2(x)
        return self.fc(x).squeeze(-1)

def compute_cmapss_score(y_true, y_pred):
    diff = y_pred - y_true
    score = np.where(diff < 0, np.exp(-diff / 13.0) - 1, np.exp(diff / 10.0) - 1)
    return np.sum(score)

def evaluate_model(model, data_loader):
    model.eval()
    all_preds, all_trues = [], []
    with torch.no_grad():
        for inputs, targets in data_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            all_preds.extend(outputs.cpu().numpy())
            all_trues.extend(targets.cpu().numpy())
    all_preds = np.array(all_preds)
    all_trues = np.array(all_trues)
    rmse = np.sqrt(mean_squared_error(all_trues, all_preds))
    mae  = mean_absolute_error(all_trues, all_preds)
    nasa = compute_cmapss_score(all_trues, all_preds)
    return rmse, mae, nasa, all_preds

os.makedirs('../models', exist_ok=True)
os.makedirs('../results/preds', exist_ok=True)
os.makedirs('../results/metrics', exist_ok=True)
os.makedirs('../results/histories', exist_ok=True)

INPUT_SIZE = X_train_arr.shape[2]
results = []

for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"SEED {seed} | Dataset {DATASET_ID} | 1D-CNN")
    print(f"{'='*60}")
    
    torch.manual_seed(seed)
    np.random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    
    train_loader = DataLoader(CMAPSSDataset(X_train_arr, y_train_arr), batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(CMAPSSDataset(X_val_arr, y_val_arr), batch_size=BATCH_SIZE, shuffle=False)
    
    model = RUL_CNN(input_features=INPUT_SIZE).to(device)
    criterion = nn.MSELoss()
    optimiser = torch.optim.Adam(model.parameters(), lr=INITIAL_LR)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser, mode='min', factor=0.5, patience=5)
    
    best_val_rmse = float('inf')
    patience_counter = 0
    best_state = None

    history = {
        "epoch": [],
        "train_rmse": [],
        "val_rmse": [],
        "val_nasa": []
    }
    
    for epoch in range(1, EPOCHS + 1):
        model.train()
        train_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimiser.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), MAX_GRAD_NORM)
            optimiser.step()
            train_loss += loss.item() * inputs.size(0)
        
        train_rmse = np.sqrt(train_loss / len(train_loader.dataset))
        
        val_rmse, val_mae, val_nasa, _ = evaluate_model(model, val_loader)
        scheduler.step(val_rmse)
        
        history["epoch"].append(epoch)
        history["train_rmse"].append(train_rmse)
        history["val_rmse"].append(val_rmse)
        history["val_nasa"].append(val_nasa)
        
        if epoch % 5 == 0 or epoch == 1:
            print(f"Epoch {epoch:02d} | Train RMSE: {train_rmse:.3f} | "
                  f"Val RMSE: {val_rmse:.3f} | MAE: {val_mae:.3f} | NASA: {val_nasa:.1f}")
        
        if val_rmse < best_val_rmse:
            best_val_rmse = val_rmse
            best_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"Early stopping at epoch {epoch}")
                break
    
    model.load_state_dict(best_state)
    final_rmse, final_mae, final_nasa, y_pred = evaluate_model(model, val_loader)
    
    torch.save(best_state, f'../models/cnn_{DATASET_ID}_seed{seed}.pt')
    np.save(f'../results/preds/cnn_pred_{DATASET_ID}_seed{seed}.npy', y_pred)
    
    hist_df = pd.DataFrame(history)
    hist_df.to_csv(f'../results/histories/cnn_{DATASET_ID}_seed{seed}.csv', index=False)
    
    if seed == 42:
        hist_df.to_csv(f'../results/histories/cnn_{DATASET_ID}.csv', index=False)
        print("Representative history (seed 42) saved for appendix.")
    
    results.append({'seed': seed, 'rmse': final_rmse, 'mae': final_mae, 'nasa': final_nasa})
    print(f"SEED {seed} FINAL → RMSE: {final_rmse:.4f} | MAE: {final_mae:.4f} | NASA: {final_nasa:.2f}")

results_df = pd.DataFrame(results)
results_df.to_csv(f'../results/metrics/cnn_{DATASET_ID}_metrics.csv', index=False)

print("\n" + "="*60)
print(f"1D-CNN – {DATASET_ID} – SUMMARY ACROSS 10 SEEDS")
print("="*60)
print(results_df.describe().round(4))
print(f"\nMean ± Std:")
print(f"RMSE : {results_df['rmse'].mean():.4f} ± {results_df['rmse'].std():.4f}")
print(f"MAE  : {results_df['mae'].mean():.4f} ± {results_df['mae'].std():.4f}")
print(f"NASA : {results_df['nasa'].mean():.2f} ± {results_df['nasa'].std():.2f}")
# Out:
# Using device: cpu
#
# ============================================================
# SEED 42 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 43.175 | Val RMSE: 22.459 | MAE: 18.101 | NASA: 146243.6
# Epoch 05 | Train RMSE: 23.103 | Val RMSE: 21.396 | MAE: 17.075 | NASA: 121277.7
# Epoch 10 | Train RMSE: 20.908 | Val RMSE: 19.755 | MAE: 15.658 | NASA: 90085.6
# Epoch 15 | Train RMSE: 19.377 | Val RMSE: 19.704 | MAE: 15.646 | NASA: 51563.6
# Epoch 20 | Train RMSE: 18.602 | Val RMSE: 18.904 | MAE: 15.115 | NASA: 67764.5
# Epoch 25 | Train RMSE: 17.332 | Val RMSE: 18.841 | MAE: 14.760 | NASA: 83772.5
# Early stopping at epoch 27
# Representative history (seed 42) saved for appendix.
# SEED 42 FINAL → RMSE: 19.2280 | MAE: 15.3667 | NASA: 79583.72
#
# ============================================================
# SEED 101 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 42.598 | Val RMSE: 22.576 | MAE: 18.163 | NASA: 155150.2
# Epoch 05 | Train RMSE: 21.962 | Val RMSE: 21.301 | MAE: 16.834 | NASA: 145282.4
# Epoch 10 | Train RMSE: 20.663 | Val RMSE: 19.095 | MAE: 15.224 | NASA: 61262.3
# Epoch 15 | Train RMSE: 19.989 | Val RMSE: 18.320 | MAE: 14.515 | NASA: 53269.9
# Epoch 20 | Train RMSE: 18.827 | Val RMSE: 19.162 | MAE: 15.538 | NASA: 70882.7
# Epoch 25 | Train RMSE: 17.849 | Val RMSE: 19.031 | MAE: 15.026 | NASA: 77617.3
# Early stopping at epoch 25
# SEED 101 FINAL → RMSE: 19.0313 | MAE: 15.0265 | NASA: 77617.27
#
# ============================================================
# SEED 2024 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 43.450 | Val RMSE: 21.667 | MAE: 17.259 | NASA: 79660.8
# Epoch 05 | Train RMSE: 22.126 | Val RMSE: 19.787 | MAE: 15.507 | NASA: 61589.0
# Epoch 10 | Train RMSE: 20.074 | Val RMSE: 18.874 | MAE: 14.948 | NASA: 76720.2
# Epoch 15 | Train RMSE: 18.963 | Val RMSE: 18.765 | MAE: 14.894 | NASA: 59343.1
# Early stopping at epoch 18
# SEED 2024 FINAL → RMSE: 18.5287 | MAE: 14.7084 | NASA: 64873.02
#
# ============================================================
# SEED 7 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 40.871 | Val RMSE: 22.661 | MAE: 18.278 | NASA: 157270.3
# Epoch 05 | Train RMSE: 22.065 | Val RMSE: 20.021 | MAE: 15.671 | NASA: 88062.1
# Epoch 10 | Train RMSE: 19.754 | Val RMSE: 19.220 | MAE: 15.059 | NASA: 93195.4
# Epoch 15 | Train RMSE: 18.757 | Val RMSE: 18.072 | MAE: 14.046 | NASA: 52986.4
# Epoch 20 | Train RMSE: 17.743 | Val RMSE: 18.764 | MAE: 15.095 | NASA: 59431.4
# Epoch 25 | Train RMSE: 16.900 | Val RMSE: 18.008 | MAE: 14.229 | NASA: 63562.3
# Epoch 30 | Train RMSE: 16.719 | Val RMSE: 18.273 | MAE: 14.001 | NASA: 85014.5
# Epoch 35 | Train RMSE: 16.066 | Val RMSE: 18.531 | MAE: 14.382 | NASA: 84495.4
# Early stopping at epoch 35
# SEED 7 FINAL → RMSE: 18.5310 | MAE: 14.3816 | NASA: 84495.39
#
# ============================================================
# SEED 88 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 42.257 | Val RMSE: 22.923 | MAE: 18.511 | NASA: 168127.9
# Epoch 05 | Train RMSE: 22.297 | Val RMSE: 20.180 | MAE: 16.051 | NASA: 78396.1
# Epoch 10 | Train RMSE: 20.998 | Val RMSE: 19.765 | MAE: 15.869 | NASA: 55261.8
# Epoch 15 | Train RMSE: 19.804 | Val RMSE: 20.538 | MAE: 16.158 | NASA: 139415.0
# Epoch 20 | Train RMSE: 18.717 | Val RMSE: 18.446 | MAE: 14.811 | NASA: 61437.1
# Epoch 25 | Train RMSE: 17.981 | Val RMSE: 18.725 | MAE: 15.025 | NASA: 63124.4
# Early stopping at epoch 29
# SEED 88 FINAL → RMSE: 18.2452 | MAE: 14.3993 | NASA: 67188.54
#
# ============================================================
# SEED 123 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 41.457 | Val RMSE: 20.980 | MAE: 16.655 | NASA: 80141.7
# Epoch 05 | Train RMSE: 22.142 | Val RMSE: 20.065 | MAE: 15.884 | NASA: 82493.7
# Epoch 10 | Train RMSE: 19.748 | Val RMSE: 18.786 | MAE: 15.030 | NASA: 79155.1
# Epoch 15 | Train RMSE: 18.378 | Val RMSE: 19.666 | MAE: 15.309 | NASA: 129928.0
# Epoch 20 | Train RMSE: 17.308 | Val RMSE: 19.027 | MAE: 14.877 | NASA: 108405.2
# Early stopping at epoch 22
# SEED 123 FINAL → RMSE: 18.0922 | MAE: 13.8939 | NASA: 83587.36
#
# ============================================================
# SEED 999 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 40.144 | Val RMSE: 21.377 | MAE: 17.040 | NASA: 106161.5
# Epoch 05 | Train RMSE: 22.691 | Val RMSE: 20.522 | MAE: 16.324 | NASA: 83526.3
# Epoch 10 | Train RMSE: 21.331 | Val RMSE: 20.288 | MAE: 16.064 | NASA: 98038.0
# Epoch 15 | Train RMSE: 20.301 | Val RMSE: 19.405 | MAE: 15.623 | NASA: 56731.9
# Epoch 20 | Train RMSE: 18.596 | Val RMSE: 18.728 | MAE: 14.677 | NASA: 75964.3
# Epoch 25 | Train RMSE: 17.989 | Val RMSE: 19.073 | MAE: 15.261 | NASA: 63978.6
# Epoch 30 | Train RMSE: 17.143 | Val RMSE: 18.794 | MAE: 14.943 | NASA: 55434.5
# Epoch 35 | Train RMSE: 16.758 | Val RMSE: 18.212 | MAE: 14.252 | NASA: 60935.7
# Epoch 40 | Train RMSE: 16.419 | Val RMSE: 18.869 | MAE: 15.024 | NASA: 68409.9
# Early stopping at epoch 41
# SEED 999 FINAL → RMSE: 18.3020 | MAE: 14.3952 | NASA: 61790.46
#
# ============================================================
# SEED 314 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 42.921 | Val RMSE: 21.861 | MAE: 17.599 | NASA: 119450.5
# Epoch 05 | Train RMSE: 22.108 | Val RMSE: 22.512 | MAE: 18.064 | NASA: 69860.6
# Epoch 10 | Train RMSE: 19.512 | Val RMSE: 17.954 | MAE: 13.802 | NASA: 73403.0
# Epoch 15 | Train RMSE: 18.862 | Val RMSE: 18.206 | MAE: 14.483 | NASA: 55312.7
# Epoch 20 | Train RMSE: 17.413 | Val RMSE: 18.028 | MAE: 14.360 | NASA: 66705.0
# Early stopping at epoch 23
# SEED 314 FINAL → RMSE: 19.1054 | MAE: 14.7571 | NASA: 111348.52
#
# ============================================================
# SEED 500 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 40.368 | Val RMSE: 21.282 | MAE: 16.976 | NASA: 101617.9
# Epoch 05 | Train RMSE: 22.484 | Val RMSE: 20.160 | MAE: 15.840 | NASA: 89844.3
# Epoch 10 | Train RMSE: 20.161 | Val RMSE: 19.186 | MAE: 15.537 | NASA: 76504.0
# Epoch 15 | Train RMSE: 19.350 | Val RMSE: 20.256 | MAE: 16.094 | NASA: 54079.4
# Epoch 20 | Train RMSE: 18.739 | Val RMSE: 18.979 | MAE: 14.806 | NASA: 86653.4
# Epoch 25 | Train RMSE: 17.873 | Val RMSE: 19.303 | MAE: 14.703 | NASA: 110890.8
# Epoch 30 | Train RMSE: 16.908 | Val RMSE: 19.048 | MAE: 14.969 | NASA: 73377.3
# Early stopping at epoch 32
# SEED 500 FINAL → RMSE: 20.0801 | MAE: 15.9648 | NASA: 68512.40
#
# ============================================================
# SEED 13 | Dataset FD002 | 1D-CNN
# ============================================================
# Epoch 01 | Train RMSE: 42.139 | Val RMSE: 21.257 | MAE: 16.732 | NASA: 82319.4
# Epoch 05 | Train RMSE: 22.696 | Val RMSE: 21.306 | MAE: 16.620 | NASA: 142289.1
# Epoch 10 | Train RMSE: 20.421 | Val RMSE: 21.542 | MAE: 16.989 | NASA: 61561.0
# Epoch 15 | Train RMSE: 19.326 | Val RMSE: 19.211 | MAE: 15.462 | NASA: 76064.8
# Epoch 20 | Train RMSE: 18.095 | Val RMSE: 20.322 | MAE: 16.316 | NASA: 61009.7
# Epoch 25 | Train RMSE: 17.191 | Val RMSE: 18.662 | MAE: 14.796 | NASA: 75001.6
# Early stopping at epoch 26
# SEED 13 FINAL → RMSE: 18.8067 | MAE: 14.6509 | NASA: 87889.49
#
# ============================================================
# 1D-CNN – FD002 – SUMMARY ACROSS 10 SEEDS
# ============================================================
#             seed     rmse      mae         nasa
# count    10.0000  10.0000  10.0000      10.0000
# mean    421.1000  18.7951  14.7544   78688.6094
# std     641.6106   0.5936   0.5832   14618.1621
# min       7.0000  18.0922  13.8939   61790.4609
# 25%      53.5000  18.3587  14.3963   67519.5039
# 50%     112.0000  18.6688  14.6796   78600.4922
# 75%     453.5000  19.0869  14.9591   84268.3828
# max    2024.0000  20.0801  15.9648  111348.5156
#
# Mean ± Std:
# RMSE : 18.7951 ± 0.5936
# MAE  : 14.7544 ± 0.5832
# NASA : 78688.61 ± 14618.16
